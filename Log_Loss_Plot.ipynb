# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrield03/Logistic-Regression-for-Spam-Classification/blob/main/Log_Loss_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Edited by: Gabriel Larot
# Last Updated: Mar 8, 2024

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/gabrield03/Logistic-Regression-for-Spam-Classification/main/Log_Loss_Iterations.csv'

loss = pd.read_csv(url)
loss
# Out:
#      Iteration  Log Loss Value
# 0            1        0.685513
# 1            2        0.679143
# 2            3        0.672732
# 3            4        0.666482
# 4            5        0.660431
# ..         ...             ...
# 195        196        0.415505
# 196        197        0.415272
# 197        198        0.415040
# 198        199        0.414811
# 199        200        0.414583
#
# [200 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))

sns.set_palette('Set3')
sns.set_style('whitegrid')

sns.lineplot(
    data=loss,
    x='Iteration',
    y='Log Loss Value',
    linewidth=2.5,
)

plt.title('Log Loss by Iteration')
# Out:
# Text(0.5, 1.0, 'Log Loss by Iteration')
